# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahAlshamrani0/IDS/blob/main/H_W_1_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Abdullah Alshamrani
# Date: Sep/6/2023
# H.W 1
#
# This notebook was created to explain H.W1 and my steps in solving Problem 1 and in problem 2. I will start with problem 1 regarding chicken and imagining myself as the next Harland Sanders (founder of KFC)

# %% [markdown]
# -- I will start by showing my table after the analyzing of chickwts.csv file on Excel below

# %% [markdown]
# ![chickwts.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Q: Based on the chicken feed data, which type of chicken food appears the most beneﬁcial for a thriving poultry business? Explain your answer.
#
#
#
#
# Answer:
# Based on the data I analyzed, I noticed that the food type "sunflower" would be more beneficial and thriving to use becaause the minumum weight we can get for the chicken will be hire from all other chickens that were feeded other types of food on the data (horsebean, linseed, soybean, meatmeal,casein.) of course this data might need other factors to decide what is more thriving popularity like (cost, egg-production, etc.)

# %% [markdown]
# # Problem 2

# %% [markdown]
# Problem 2: I have a table that contains an imaginary dataset of auto insurance providers and their ratings as provided by the latest three customers.

# %% [markdown]
# I created a .csv file for the table ans saved it in github and H.W 1 repository. and I will preform similar analysis on it
#
# Below is the table and my analysis

# %% [markdown]
# ![Screen Shot 2023-09-07 at 12.01.44 AM.png](data:image/png;base64,...)

# %% [markdown]
# Q: determine if you had to choose an auto insurance provider based on these ratings, which one you would opt for. Explain your answer.
#
#
#
# Answer: I would likely go with Progressive insurance company. because of two factors I have noticed on my analysis, the first one is, Progressive has a low mean rate which indicates lower premium cost. and my second reason, they have the highest sum of ratings which is 23 this shows there is a high customer satisfaction. and also the minumum rate for progressive according to the analysis was not bad like the other two companies on the table and was not under 6.5.

# %% [markdown]
# # END OF ANALYSIS
