# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahAlshamrani0/IDS/blob/main/Problem1_of_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Abdullah Alshamrani
# Date: 09/21/2023
#
# This notebook will explain throughly what I did to solve problem#1 a in project2

# %% [markdown]
# **PROBLEM 1**

# %% [markdown]
# A. First we started with Exel. I addressed all missing values and changed it with a constant value of 0
#
# # B. Look for outliers and smooth noisy data, if any.
# No any outliers and smooth noisy data
#
# C. Plot Murder rates for all 50 states
# ![Murder Rates of all 50 states.png](data:image/png;base64,...)

# %% [markdown]
# D. Plot histogram of assaults
# ![Assault Histogram.png](data:image/png;base64,...)

# %% [markdown]
# E. Plot Murder rate vs. Assault rate.
# ![murder vs assault crime rate.png](data:image/png;base64,...)

# %% [markdown]
# Prepare the dataset to establish a relation between an urban population category and a crime type. Hint: Convert the urban population percentage into categories, for example, small (<50%), medium (<60%), large (<70%), and extra-large (70% and above) urban population.
#
# DONE
# I did establish the relationship and made a new column with the name of "UrbanPop Catagories"

# %% [markdown]
# #SQL
#
#
#
#
# C. Find min, max, mean, and variance of all numeric attributes in SQL.
# ![Screenshot 2023-09-21 at 1.31.14 PM.png](data:image/png;base64,...)

# %% [markdown]
# D. Use SQL to answer the following questions:
# -- Which state has the maximum murder rate?
#   Georgia -->
# SELECT State
# FROM mytable
# WHERE Murder = (SELECT MAX(Murder) FROM mytable); result: Georgia
#
#
# -- List of states in ascending order of urban population percentages.
# State
#
# * Vermont
# * West Virginia
# * Mississippi
# * North Dakota
# * North Carolina
# * South Dakota
# * Alaska
# * South Carolina
# * Arkansas
# * Maine
# * Kentucky
# * Montana
# * Idaho
# * New Hampshire
# * Iowa
# * Alabama
# * Tennessee
# * Georgia
# * Wyoming
# * Nebraska
# * Virginia
# * Indiana
# * Kansas
# * Louisiana
# * Minnesota
# * Wisconsin
# * Maryland
# * Oregon
# * Oklahoma
# * Missouri
# * New Mexico
# * Delaware
# * Pennsylvania
# * Washington
# * Michigan
# * Ohio
# *Connecticut
# *Colorado
# *Arizona
# *Florida
# *Texas
# *Utah
# *Nevada
# *Hawaii
# *Illinois
# *Massachusetts
# *New York
# *Rhode Island
# *New Jersey
# *California
#
#
#
#
#
#
#
# -- How many states have higher murder rates than Arizona? List those states.
#
# * Alabama	13.2
# * Alaska	10
# * Arkansas	8.8
# * California	9
# * Florida	15.4
# *Georgia	17.4
# *Illinois	10.4
# *Kentucky	9.7
# *Louisiana	15.4
# *Maryland	11.3
# *Michigan	12.1
# *Mississippi	16.1
# *Missouri	9
# *Nevada	12.2
# *New Mexico	11.4
# *New York	11.1
# *North Carolina	13
# *South Carolina	14.4
# *Tennessee	13.2
# *Texas	12.7
# *Virginia	8.5
